# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_excel("./data/xi_array.csv",header=None)

# %%
data
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.048321  0.037088 -0.008474 -0.015425  0.009358  0.009401 -0.010329
# 1   0.037088  0.043589  0.027482  0.014400 -0.019432  0.004481  0.015035
# 2  -0.008474  0.027482  0.037623  0.033562  0.006859 -0.009560  0.025347
# 3  -0.015425  0.014400  0.033562  0.020427  0.024153 -0.018279 -0.023921
# 4   0.009358 -0.019432  0.006859  0.024153  0.033128  0.035346 -0.010998
# 5   0.009401  0.004481 -0.009560 -0.018279  0.035346  0.083069  0.075065
# 6  -0.010329  0.015035  0.025347 -0.023921 -0.010998  0.075065  0.126012
# 7  -0.005931  0.014182  0.008243  0.019558 -0.016803 -0.003236  0.095288
# 8   0.024500 -0.031569 -0.029094  0.031270  0.006408 -0.053626 -0.043600
# 9   0.003238  0.008394 -0.003548 -0.021665  0.008754  0.044015 -0.043173
# 10 -0.038828  0.063020  0.016144 -0.077873  0.010289  0.068410  0.041784
# 11 -0.031571  0.085534  0.000165 -0.109146 -0.105279  0.127833  0.031826
# ...

# %%
data.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of           0         1         2         3         4         5         6   \
# 0   0.048321  0.037088 -0.008474 -0.015425  0.009358  0.009401 -0.010329
# 1   0.037088  0.043589  0.027482  0.014400 -0.019432  0.004481  0.015035
# 2  -0.008474  0.027482  0.037623  0.033562  0.006859 -0.009560  0.025347
# 3  -0.015425  0.014400  0.033562  0.020427  0.024153 -0.018279 -0.023921
# 4   0.009358 -0.019432  0.006859  0.024153  0.033128  0.035346 -0.010998
# 5   0.009401  0.004481 -0.009560 -0.018279  0.035346  0.083069  0.075065
# 6  -0.010329  0.015035  0.025347 -0.023921 -0.010998  0.075065  0.126012
# 7  -0.005931  0.014182  0.008243  0.019558 -0.016803 -0.003236  0.095288
# 8   0.024500 -0.031569 -0.029094  0.031270  0.006408 -0.053626 -0.043600
# 9   0.003238  0.008394 -0.003548 -0.021665  0.008754  0.044015 -0.043173
# 10 -0.038828  0.063020  0.016144 -0.077873  0.010289  0.068410  0.041784
# ...

# %%
# ax = sns.heatmap(data)
plt.imshow(data, 'jet')
plt.show()

# %%
data2 = pd.read_excel('./data/xi_array_iamg.csv',header=None)

# %%
plt.imshow(data2, 'jet')
plt.show()

# %%
mu_array1  = pd.read_excel('./data/mu_array1.csv',header=None)

# %%
plt.imshow(mu_array1, 'jet')
plt.colorbar()
plt.show()
